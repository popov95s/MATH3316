# %% [markdown]
# ### Part 2
#
# For the second part of the project we had to compute the forward difference estimates of the derivative $f'(3)$ of the function $f(x) = x^{-3}$ with the sequence of increments $h=2^{-n}$, where n is in $[1,52]$. We then had to compute both the relative error $r$ in the approximation for each of the increments, as well as the upper bound on the relative error $R$ from a derivation that was previously provided.

# %% [markdown]
# The code used implemented the provided derivations, with separate functions for each part of the equations, making use of std::vector, the math.h library, as well as the provided Matrix class to write to a text file.

# %%
# %pylab inline
n= loadtxt("n.txt")
h= loadtxt("h.txt")
r = loadtxt("r.txt")
R = loadtxt("R.txt")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-3be0986df743> in <module>()
#       1 get_ipython().magic('pylab inline')
# ----> 2 n= loadtxt("n.txt")
#       3 h= loadtxt("h.txt")
#       4 r = loadtxt("r.txt")
#       5 R = loadtxt("R.txt")
#
# /home/spopov/anaconda3/lib/python3.5/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     803                 fh = iter(open(fname, 'U'))
#     804             else:
# --> 805                 fh = iter(open(fname))
#     806         else:
#     807             fh = iter(fname)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'n.txt'

# %%
semilogy(n, r, label= 'r vs n', color = 'blue')
semilogy(n, R, label= 'R vs n', color = 'red')
xlabel('n')
ylabel('r and R')
title('Relative error and upper bound in $f(x)=x^{-3}$')
legend()

# %%
loglog(h, r, label= 'r vs h', color = 'blue')
loglog(h, R, label= 'R vs h', color = 'red')
xlabel('h')
ylabel('r and R')
title('Sequence of increments vs r and R')
legend()

# %% [markdown]
# Based on the above computations and plots, we can see that r and R decrease as h decreases. The same happens with r and R when plotted against n. We can also notice that the closest approximations come for $n < 24$ and $h > 10^{-7}$. These derivations show consistency, since a larger n would result in a smaller h, and the plots clearly show that, with the ranges in which r and R are closest together.
