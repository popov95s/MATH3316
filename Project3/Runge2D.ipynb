# %% [markdown]
# # Runge2D testing script

# %% [raw]
# MATH3316 Project3
# Author: Stefan Popov
# Oct 23rd 2016

# %% [markdown]
# Loading all data output by Runge_uniform.cpp and Runge_Chebyshev.cpp

# %%
# %pylab inline
p6_uni = loadtxt('p6_uni.txt')
p24_uni = loadtxt('p24_uni.txt')
p6_Cheb = loadtxt('p6_Cheb.txt')
p24_Cheb = loadtxt('p24_Cheb.txt')
Runge = loadtxt('Runge.txt')
a= loadtxt('avals.txt')
b= loadtxt('bvals.txt')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D
fig = figure()
ax = fig.add_subplot(111, projection='3d')
X, Y = meshgrid(b, a)
surf = ax.plot_surface(X, Y, Runge, rstride=1, cstride=1, linewidth=0, cmap=cm.jet)
ax.set_xlabel('x')
ax.set_ylabel('y')
title('$f(x,y)$')

# %%
fig = figure()
ax = fig.add_subplot(111, projection='3d')
X, Y = meshgrid(b, a)
surf = ax.plot_surface(X, Y, p6_uni, rstride=1, cstride=1, linewidth=0, cmap=cm.jet)
ax.set_xlabel('x')
ax.set_ylabel('y')
title('$p_6$ for uniformly spaced nodes')

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D
fig = figure()
ax = fig.add_subplot(111, projection='3d')
X, Y = meshgrid(b, a)
surf = ax.plot_surface(X, Y, p24_uni, rstride=1, cstride=1, linewidth=0, cmap=cm.jet)
ax.set_xlabel('x')
ax.set_ylabel('y')
title('$p_{24}$ for uniformly spaced nodes')

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D
fig = figure()
ax = fig.add_subplot(111, projection='3d')
X, Y = meshgrid(b, a)
surf = ax.plot_surface(X, Y, p6_Cheb, rstride=1, cstride=1, linewidth=0, cmap=cm.jet)
ax.set_xlabel('x')
ax.set_ylabel('y')
title('$p_6$ for Chebyshev nodes')

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D
fig = figure()
ax = fig.add_subplot(111, projection='3d')
X, Y = meshgrid(b, a)
surf = ax.plot_surface(X, Y, p24_Cheb, rstride=1, cstride=1, linewidth=0, cmap=cm.jet)
ax.set_xlabel('x')
ax.set_ylabel('y')
title('$p_{24}$ for uniformly spaced nodes')

# %%
error6_uni=numpy.ndarray((201,101))
for i in range(0,201):
    for j in range(0,101):
      error6_uni[i][j]= Runge[i][j]- p6_uni[i][j]
from mpl_toolkits.mplot3d.axes3d import Axes3D
fig = figure()
ax = fig.add_subplot(111, projection='3d')
X, Y = meshgrid(b, a)
surf = ax.plot_surface(X, Y, error6_uni, rstride=1, cstride=1, linewidth=0, cmap=cm.jet)
ax.set_xlabel('x')
ax.set_ylabel('y')
title('$f(x,y)$')

# %%
error24_uni=numpy.ndarray((201,101))
for i in range(0,201):
    for j in range(0,101):
      error24_uni[i][j]= Runge[i][j]- p24_uni[i][j]
from mpl_toolkits.mplot3d.axes3d import Axes3D
fig = figure()
ax = fig.add_subplot(111, projection='3d')
X, Y = meshgrid(b, a)
surf = ax.plot_surface(X, Y, error24_uni, rstride=1, cstride=1, linewidth=0, cmap=cm.jet)
ax.set_xlabel('x')
ax.set_ylabel('y')
title('Error 24 for uniformly spaced nodes')

# %%
error6_Cheb=numpy.ndarray((201,101))
for i in range(0,201):
    for j in range(0,101):
      error6_Cheb[i][j]= Runge[i][j]- p6_Cheb[i][j]
from mpl_toolkits.mplot3d.axes3d import Axes3D
fig = figure()
ax = fig.add_subplot(111, projection='3d')
X, Y = meshgrid(b, a)
surf = ax.plot_surface(X, Y, error6_Cheb, rstride=1, cstride=1, linewidth=0, cmap=cm.jet)
ax.set_xlabel('x')
ax.set_ylabel('y')
title('$f(x,y)$')

# %%
error24_Cheb=numpy.ndarray((201,101))
for i in range(0,201):
    for j in range(0,101):
      error24_Cheb[i][j]= Runge[i][j]- p24_Cheb[i][j]
from mpl_toolkits.mplot3d.axes3d import Axes3D
fig = figure()
ax = fig.add_subplot(111, projection='3d')
X, Y = meshgrid(b, a)
surf = ax.plot_surface(X, Y, error24_Cheb, rstride=1, cstride=1, linewidth=0, cmap=cm.jet)
ax.set_xlabel('x')
ax.set_ylabel('y')
title('$f(x,y)$')
